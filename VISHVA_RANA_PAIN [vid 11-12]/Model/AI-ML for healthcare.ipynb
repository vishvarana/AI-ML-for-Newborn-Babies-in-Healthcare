# %%
import cv2
import os
videos=glob.glob('C:/Users/Yuvraj/Desktop/Vishva') # I have passed the source folder where the videos(whose frames are to be extracted) are present
np_video_list=[]#I have created an empty list to store the source videos 
for video in videos: #This for loop is to iterate over videos in folder
    for v in glob.glob(video+'/*.mp4'): # to make sure that videos with mp4 extension are being iterated
        np_video_list.append(v) #I have add the videos with mp4 extension, using append
i=1
frame_no=1
for j in range(0,len(np_video_list)): #To iterate over the videos added to the list
    video_data=np_video_list[j]
    cap=cv2.VideoCapture(video_data) #To open the video file
    
    while cap.isOpened():
        ret,frame=cap.read()
        if ret:
            i = i + 1
            if i % 12 == 0:
                name = 'C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB' + '/' +'PAIN' + str(frame_no) + '.jpg' #name and location of frames to be saved, one can declare location outside too
                cv2.imwrite(name, frame)
                    
                print('Creating ' + name)
                frame_no+=1
        else:
            break
    cap.release()
# Out:
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN1.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN2.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN3.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN4.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN5.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN6.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN7.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN8.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN9.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN10.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN11.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN12.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN13.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN14.jpg
# Creating C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB/PAIN15.jpg
# ...

# %%
from os import listdir,makedirs

from os.path import isfile,join
path = 'C:/Users/Yuvraj/Desktop/Vishva/ImageData/RGB' # Source Folder
dstpath = 'C:/Users/Yuvraj/Desktop/Vishva/ImageData/GRAY' # Destination Folder
try:
    makedirs(dstpath)# in case, the destination folder aka directory is not present, it will be created
except:
    print ("Directory already exist, images will be written in same folder")
    
files = list(filter(lambda f: isfile(join(path,f)), listdir(path))) #for all files in the directory
for image in files:
    try:
        img = cv2.imread(os.path.join(path,image))
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) 
        dstPath = join(dstpath,image)
        cv2.imwrite(dstPath,gray)
    except:
        print ("{} is not converted".format(image))
for fil in glob.glob("*.jpg"):
    try:
        image = cv2.imread(fil) 
        gray_image = cv2.cvtColor(os.path.join(path,image), cv2.COLOR_BGR2GRAY) # convert to grayscale
        cv2.imwrite(os.path.join(dstpath,fil),gray_image)
    except:
        print('{} is not converted')
# Out:
# Directory already exist, images will be written in same folder
